# %%
reducelronplateau_history = [31.71155957720352, 80.03911148541063, 81.35184205753613, 81.00783376102964, 81.52502761693862, 81.49882251033266, 81.32444769023746, 81.30301786722973]
cosineannealing_history = [30.03705784344448, 71.21169939356716, 80.28705123610565, 80.91319725515686, 81.2086809465099, 81.2720169340465, 81.45665869796264, 81.23707123737132, 81.25580253098529, 81.46135001989923, 81.42048634140922, 81.43272260242368, 81.59416064944996, 81.72546931898309, 81.48377162343508, 81.45341874033252, 81.59194014189717]
onecyclelr_history = [30.034069121719387, 29.830048056373105, 29.758759883227942, 29.985647003501153]
multisteplr_history = [30.069081546543014, 79.50234810408612, 81.04032289230267, 81.18631093529993, 81.21114333546721, 81.27430241563077, 81.26097327781244, 81.08296939195407, 81.2352080959506]

# %%
import matplotlib.pyplot as plt

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(reducelronplateau_history, label='ReduceLROnPlateau')
plt.plot(cosineannealing_history, label='CosineAnnealingLR')
plt.plot(onecyclelr_history, label='OneCycleLR')
plt.plot(multisteplr_history, label='MultiStepLR')

plt.xlabel('Epochs')
plt.ylabel('BLEU Score')
plt.title('BLEU Score History with Different Schedulers')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plotting
plt.figure(figsize=(10, 6))
plt.plot(reducelronplateau_history, label='ReduceLROnPlateau')
plt.plot(cosineannealing_history, label='CosineAnnealingLR')
plt.plot(onecyclelr_history, label='OneCycleLR')
plt.plot(multisteplr_history, label='MultiStepLR')

plt.xlabel('Epochs')
plt.ylabel('BLEU Score')
plt.title('BLEU Score History with Different Schedulers (Zoomed In)')
plt.ylim(78, 83)  # Set y-axis limits to zoom in on scores between 78 and 83
plt.legend()
plt.grid(True)
plt.show()
